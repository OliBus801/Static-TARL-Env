# %%
from network import TapScenario

# %%
# Creating Scenario Object
scenario = TapScenario()

# Loading Network
scenario.load_network_from_json("../data/scenarios/test/test_network.json")

# Loading Demand
scenario.load_demand_from_json("../data/scenarios/test/test_demand.json")
# Out:
# ✅ Successfully loaded network from JSON file!
# 🌐 Network Info: 2 nodes, 2 edges.
# ✅ Successfully loaded demand from JSON file!
# 👥 Demand Info: Total agents = 10.

# %%
scenario.calculate_system_cost([5, 5])
# Out:
# ✅ Flow consistency check passed.
# ---------- Link #0 ----------
# Calculating travel time on link 0 -> 1 with capacity 10 and freeflow_travel_time 60
# Coût : 60.56249999999999 sec. * 5 agents = 302.81249999999994
# ---------- Link #1 ----------
# Calculating travel time on link 0 -> 1 with capacity 5 and freeflow_travel_time 30
# Coût : 34.5 sec. * 5 agents = 172.5
# Coût total du système : 475.31249999999994
# 475.31249999999994
